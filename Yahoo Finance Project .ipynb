# %% [markdown]
# # Finance Data Project

# %% [markdown]
# In this project we will see how to use pandas to directly read data from Google finance using pandas!
#
# Note: You'll need to install pandas-datareader for this to work! Pandas datareader allows you to read stock information directly from the internet (pip install pandas-datareader).

# %% [markdown]
# ### Get The Data

# %% [markdown]
# We need to install **pip install pandas-datareader**

# %% [markdown]
# ### The Imports

# %%
import pandas as pd
import pandas_datareader as dr
# %matplotlib inline

# %% [markdown]
# # Data
#
# We need to get data using pandas datareader.
#
# ** Figure out how to get the stock data from Nov 9th 2018 to Oct 10th 2018 for each of these.
#
# ** Use [this documentation page](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html#yahoo-finance-data) for hints and instructions (it should just be a matter of replacing certain values. Use google finance as a source.
#
#
# ### WARNING: MAKE SURE TO CHECK THE LINK ABOVE FOR THE LATEST WORKING API. "google" MAY NOT ALWAYS WORK.

# %%
df = dr.data.get_data_yahoo('ibm' , start='2018-09-27' , end='2018-10-23')

# %%
df
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2018-09-26  153.350006  151.339996  152.399994  151.610001   7401900
# 2018-09-27  152.389999  151.160004  152.009995  151.500000   3477600
# 2018-09-28  151.630005  150.789993  151.160004  151.210007   3305800
# 2018-10-01  153.419998  151.710007  151.710007  153.000000   3757400
# 2018-10-02  153.839996  152.500000  152.990005  153.750000   3029900
# 2018-10-03  154.360001  152.800003  154.000000  153.220001   3315300
# 2018-10-04  152.800003  150.360001  151.690002  151.309998   4237900
# 2018-10-05  151.789993  147.869995  150.899994  149.029999   4602200
# 2018-10-08  149.070007  147.179993  148.500000  148.389999   3239300
# 2018-10-09  148.360001  146.929993  148.080002  147.240005   3642400
# 2018-10-10  147.690002  142.500000  147.500000  142.690002   5547700
# 2018-10-11  144.190002  138.779999  142.619995  139.020004   8710500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20 entries, 2018-09-26 to 2018-10-23
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       20 non-null     float64
#  1   Low        20 non-null     float64
#  2   Open       20 non-null     float64
#  3   Close      20 non-null     float64
#  4   Volume     20 non-null     int64
#  5   Adj Close  20 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 1.1 KB

# %%
df[['Open', 'Close']].plot(figsize=(15,5));

# %%
df.loc['2018-10-01':'2018-10-05' ,['Open' , 'Close']].plot(figsize=(15,5));

# %%
df['Close'].pct_change()
# Out:
# Date
# 2018-09-26         NaN
# 2018-09-27   -0.000726
# 2018-09-28   -0.001914
# 2018-10-01    0.011838
# 2018-10-02    0.004902
# 2018-10-03   -0.003447
# 2018-10-04   -0.012466
# 2018-10-05   -0.015068
# 2018-10-08   -0.004294
# 2018-10-09   -0.007750
# 2018-10-10   -0.030902
# 2018-10-11   -0.025720
# 2018-10-12    0.013164
# 2018-10-15    0.001988
# 2018-10-16    0.028272
# 2018-10-17   -0.076282
# 2018-10-18   -0.026110
# 2018-10-19   -0.011107
# 2018-10-22    0.007126
# 2018-10-23    0.009152
# Name: Close, dtype: float64

# %%
df['Close'].pct_change().plot();

# %%
df['2018-10']
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2018-10-01  153.419998  151.710007  151.710007  153.000000   3757400
# 2018-10-02  153.839996  152.500000  152.990005  153.750000   3029900
# 2018-10-03  154.360001  152.800003  154.000000  153.220001   3315300
# 2018-10-04  152.800003  150.360001  151.690002  151.309998   4237900
# 2018-10-05  151.789993  147.869995  150.899994  149.029999   4602200
# 2018-10-08  149.070007  147.179993  148.500000  148.389999   3239300
# 2018-10-09  148.360001  146.929993  148.080002  147.240005   3642400
# 2018-10-10  147.690002  142.500000  147.500000  142.690002   5547700
# 2018-10-11  144.190002  138.779999  142.619995  139.020004   8710500
# 2018-10-12  141.539993  139.080002  141.119995  140.850006   6563400
# 2018-10-15  142.259995  140.139999  140.380005  141.130005   4965500
# 2018-10-16  145.449997  141.580002  142.929993  145.119995   8695500
# ...
